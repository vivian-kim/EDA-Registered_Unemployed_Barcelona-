# %%
#Barcelona registered Unemploymentrate

# %%
import pandas as pd
import glob
import numpy as np
import geopandas
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import matplotlib as mpl
# !pip3 install bokeh
from bokeh.plotting import figure, show
from matplotlib.pyplot import figure

# %%
# get data file names
path ='/Users/mitarbeiter/datascience_project/unemployment'
filenames = glob.glob(path + "/*.csv")
print(filenames)
# Out:
# ['/Users/mitarbeiter/datascience_project/unemployment/2019_Atur_per_sexe.csv', '/Users/mitarbeiter/datascience_project/unemployment/2020_Atur_per_sexe.csv', '/Users/mitarbeiter/datascience_project/unemployment/2021_Atur_per_sexe.csv']

# %%
# read all the *.csv inside unemployment 

unemployment = []
for file in filenames:
    df_per_year = pd.read_csv(file)
    unemployment.append(df_per_year)
    print(f'Size of {file}: {df_per_year.shape}')
# Out:
# Size of /Users/mitarbeiter/datascience_project/unemployment/2019_Atur_per_sexe.csv: (3552, 9)
# Size of /Users/mitarbeiter/datascience_project/unemployment/2020_Atur_per_sexe.csv: (3552, 9)
# Size of /Users/mitarbeiter/datascience_project/unemployment/2021_Atur_per_sexe.csv: (592, 9)

# %%
# combine all dataframe 
df = pd.concat(unemployment, axis=0, ignore_index=True)
print(df.shape)
df.head(2)
# Out:
# (7696, 9)
#     Any  Mes  Codi_Districte Nom_Districte  Codi_Barri       Nom_Barri   Sexe  \
# 0  2019    1               1  Ciutat Vella           1        el Raval  Homes
# 1  2019    1               1  Ciutat Vella           2  el Barri Gòtic  Homes
#
#   Demanda_ocupacio  Nombre
# 0   Atur registrat    1900
# 1   Atur registrat     485

# %%
df = df.rename(columns={'Any':'year',
                   'Mes':'month', 
                   'Codi_Districte':'district_code', 
                   'Nom_Districte':'district_name', 
                   'Codi_Barri':'neighbourhood_code', 
                   'Nom_Barri':'neighbourhood_name', 
                'Sexe':'sex','Demanda_ocupacio':'Demand_occupation',
                   'Nombre':'number', })
df.head(2)
# Out:
#    year  month  district_code district_name  neighbourhood_code  \
# 0  2019      1              1  Ciutat Vella                   1
# 1  2019      1              1  Ciutat Vella                   2
#
#   neighbourhood_name    sex Demand_occupation  number
# 0           el Raval  Homes    Atur registrat    1900
# 1     el Barri Gòtic  Homes    Atur registrat     485

# %% [markdown]
# #### Downloaded Csv files didn't have all same format so i separated them into two folders, and changed the name and concat them again

# %% [markdown]
# #### Let's do the second part

# %%
# get data file names
path ='/Users/mitarbeiter/datascience_project/unemployment/unemployment2'
filenames = glob.glob(path + "/*.csv")
print(filenames)
# Out:
# ['/Users/mitarbeiter/datascience_project/unemployment/unemployment2/2018_Atur_per_sexe.csv', '/Users/mitarbeiter/datascience_project/unemployment/unemployment2/2016_atur_per_sexe.csv', '/Users/mitarbeiter/datascience_project/unemployment/unemployment2/2013_atur_per_sexe.csv', '/Users/mitarbeiter/datascience_project/unemployment/unemployment2/2017_atur_per_sexe.csv', '/Users/mitarbeiter/datascience_project/unemployment/unemployment2/2012_atur_per_sexe.csv', '/Users/mitarbeiter/datascience_project/unemployment/unemployment2/2014_atur_per_sexe.csv', '/Users/mitarbeiter/datascience_project/unemployment/unemployment2/2011_atur_per_sexe.csv', '/Users/mitarbeiter/datascience_project/unemployment/unemployment2/2015_atur_per_sexe.csv']

# %%
# read all the *.csv inside unemployment 

unemployment2 = []
for file in filenames:
    df_per_year = pd.read_csv(file)
    unemployment2.append(df_per_year)
    print(f'Size of {file}: {df_per_year.shape}')
# Out:
# Size of /Users/mitarbeiter/datascience_project/unemployment/unemployment2/2018_Atur_per_sexe.csv: (3552, 9)
# Size of /Users/mitarbeiter/datascience_project/unemployment/unemployment2/2016_atur_per_sexe.csv: (3552, 9)
# Size of /Users/mitarbeiter/datascience_project/unemployment/unemployment2/2013_atur_per_sexe.csv: (1776, 9)
# Size of /Users/mitarbeiter/datascience_project/unemployment/unemployment2/2017_atur_per_sexe.csv: (3552, 9)
# Size of /Users/mitarbeiter/datascience_project/unemployment/unemployment2/2012_atur_per_sexe.csv: (1776, 9)
# Size of /Users/mitarbeiter/datascience_project/unemployment/unemployment2/2014_atur_per_sexe.csv: (1776, 9)
# Size of /Users/mitarbeiter/datascience_project/unemployment/unemployment2/2011_atur_per_sexe.csv: (1776, 9)
# Size of /Users/mitarbeiter/datascience_project/unemployment/unemployment2/2015_atur_per_sexe.csv: (3552, 9)

# %%
# combine all dataframe 
df2 = pd.concat(unemployment2, axis=0, ignore_index=True)
print(df.shape)
df2.head(2)
# Out:
# (7696, 9)
#     Any  Mes  Codi_Districte Nom_Districte  Codi_Barri       Nom_Barri   Sexe  \
# 0  2018    1               1  Ciutat Vella           1        el Raval  Homes
# 1  2018    1               1  Ciutat Vella           2  el Barri Gòtic  Homes
#
#   Demanda_ocupació  Nombre
# 0   Atur registrat    2026
# 1   Atur registrat     493

# %%
df2 = df2.rename(columns={'Any':'year',
                   'Mes':'month', 
                   'Codi_Districte':'district_code', 
                   'Nom_Districte':'district_name', 
                   'Codi_Barri':'neighbourhood_code', 
                   'Nom_Barri':'neighbourhood_name', 
                'Sexe':'sex','Demanda_ocupació':'Demand_occupation',
                   'Nombre':'number', })
df2.head(2)
# Out:
#    year  month  district_code district_name  neighbourhood_code  \
# 0  2018      1              1  Ciutat Vella                   1
# 1  2018      1              1  Ciutat Vella                   2
#
#   neighbourhood_name    sex Demand_occupation  number
# 0           el Raval  Homes    Atur registrat    2026
# 1     el Barri Gòtic  Homes    Atur registrat     493

# %%
df=pd.DataFrame(df)
df2=pd.DataFrame(df2)

# %%
df['year'].unique()
# Out:
# array([2019, 2020, 2021])

# %%
df2['year'].unique()
# Out:
# array([2018, 2016, 2013, 2017, 2012, 2014, 2011, 2015])

# %%
final= pd.concat([df, df2], ignore_index=True)

# %% [markdown]
# #### I combined all datasets

# %%
print("final shape is" ,final.shape)
final.head(2)
# Out:
# final shape is (29008, 9)
#    year  month  district_code district_name  neighbourhood_code  \
# 0  2019      1              1  Ciutat Vella                   1
# 1  2019      1              1  Ciutat Vella                   2
#
#   neighbourhood_name    sex Demand_occupation  number
# 0           el Raval  Homes    Atur registrat    1900
# 1     el Barri Gòtic  Homes    Atur registrat     485

# %%
final['Demand_occupation']=final['Demand_occupation'].replace(
    {'Atur registrat': 'Registered Unemployment'})
final['Demand_occupation']=final['Demand_occupation'].replace(
    {'Demanda no aturats':'Unemployed Demand'})
final['Demand_occupation']=final['Demand_occupation'].replace(
   {'Atur Registrat':'Registered Unemployment'})
final['Demand_occupation']=final['Demand_occupation'].replace(
    {'Demanda No Aturats':'Unstoppable Demand'})

# %%
final
# Out:
#        year  month  district_code district_name  neighbourhood_code  \
# 0      2019      1              1  Ciutat Vella                   1
# 1      2019      1              1  Ciutat Vella                   2
# 2      2019      1              1  Ciutat Vella                   3
# 3      2019      1              1  Ciutat Vella                   4
# 4      2019      1              2      Eixample                   5
# ...     ...    ...            ...           ...                 ...
# 29003  2015     12             10    Sant Martí                  70
# 29004  2015     12             10    Sant Martí                  71
# 29005  2015     12             10    Sant Martí                  72
# 29006  2015     12             10    Sant Martí                  73
# 29007  2015     12             99     No consta                  99
#
#                           neighbourhood_name    sex        Demand_occupation  \
# ...

# %% [markdown]
# #### EDA

# %%
final_2011_graph=final[final['year']==2011]
final_2012_graph=final[final['year']==2012]
final_2013_graph=final[final['year']==2013]
final_2014_graph=final[final['year']==2014]
final_2015_graph=final[final['year']==2015]
final_2016_graph=final[final['year']==2016]
final_2017_graph=final[final['year']==2017]
final_2018_graph=final[final['year']==2018]
final_2019_graph=final[final['year']==2019]
final_2020_graph=final[final['year']==2020]
final_2021_graph=final[final['year']==2021]

# %%
grouped_df = final_2011_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()

plt.figure(figsize=(8,4))
sns.pointplot(grouped_df['district_name'].values, grouped_df['number'].values, alpha=0.8, color='blue')
plt.ylabel('sum', fontsize=12)
plt.xlabel('district_name', fontsize=12)
plt.title("Total number of unemployed peeps per district 2011", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
grouped_df_2 = final_2020_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()

plt.figure(figsize=(8,4))
sns.pointplot(grouped_df_2['district_name'].values, grouped_df_2['number'].values, alpha=0.8, color='skyblue')
plt.ylabel('sum', fontsize=12)
plt.xlabel('district_name', fontsize=12)
plt.title("Total number of unemployed peeps per district 2020", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
grouped_df_3 = final_2021_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()

plt.figure(figsize=(8,4))
sns.pointplot(grouped_df_3['district_name'].values, grouped_df_3['number'].values, alpha=0.8, color='black')
plt.ylabel('sum', fontsize=12)
plt.xlabel('district_name', fontsize=12)
plt.title("Total number of unemployed peeps per district 2021", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
grouped_df_2011 = final_2011_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()
grouped_df_2012 = final_2012_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()
grouped_df_2013 = final_2013_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()
grouped_df_2014 = final_2014_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()
grouped_df_2015 = final_2015_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()
grouped_df_2016 = final_2016_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()
grouped_df_2017 = final_2017_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()
grouped_df_2018 = final_2018_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()
grouped_df_2019 = final_2019_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()
grouped_df_2020 = final_2020_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()
grouped_df_2021 = final_2021_graph.groupby(["district_name"])["number"].aggregate("sum").reset_index()

# %%
grouped_df_2011=grouped_df_2011.rename(columns = {'number': '2011'}, inplace = False)
grouped_df_2012=grouped_df_2012.rename(columns = {'number': '2012'}, inplace = False)
grouped_df_2013=grouped_df_2013.rename(columns = {'number': '2013'}, inplace = False)
grouped_df_2014=grouped_df_2014.rename(columns = {'number': '2014'}, inplace = False)
grouped_df_2015=grouped_df_2015.rename(columns = {'number': '2015'}, inplace = False)
grouped_df_2016=grouped_df_2016.rename(columns = {'number': '2016'}, inplace = False)
grouped_df_2017=grouped_df_2017.rename(columns = {'number': '2017'}, inplace = False)
grouped_df_2018=grouped_df_2018.rename(columns = {'number': '2018'}, inplace = False)
grouped_df_2019=grouped_df_2019.rename(columns = {'number': '2019'}, inplace = False)
grouped_df_2020=grouped_df_2020.rename(columns = {'number': '2020'}, inplace = False)
grouped_df_2021=grouped_df_2021.rename(columns = {'number': '2021'}, inplace = False)

# %% [markdown]
# #### so I just realised that I can just make a dataframe first so I am going to create all lists. I am not using functions for today

# %%
merging=grouped_df_2011.merge(grouped_df_2012, on='district_name', how='left')
merging2=merging.merge(grouped_df_2013, on='district_name', how='left')
merging3=merging2.merge(grouped_df_2014, on='district_name', how='left')
merging4=merging3.merge(grouped_df_2015, on='district_name', how='left')
merging5=merging4.merge(grouped_df_2016, on='district_name', how='left')
merging6=merging5.merge(grouped_df_2017, on='district_name', how='left')
merging7=merging6.merge(grouped_df_2018, on='district_name', how='left')
merging8=merging7.merge(grouped_df_2019, on='district_name', how='left')
merging9=merging8.merge(grouped_df_2020, on='district_name', how='left')
merging10=merging9.merge(grouped_df_2021, on='district_name', how='left')

# %%
clean_data=merging10
clean_data
# Out:
#           district_name    2011    2012    2013    2014    2015    2016  \
# 0          Ciutat Vella  118149  117112  111245  103594  119131  108314
# 1              Eixample  183018  192024  185128  169837  190472  169554
# 2                Gràcia   88700   92968   89141   81295   91576   81524
# 3        Horta-Guinardó  138138  146129  145411  135543  150144  134106
# 4             Les Corts   51314   53511   52504   49570   56920   50409
# 5             No consta      86      75      54      62     131     177
# 6            Nou Barris  164580  175513  177627  167536  185439  165362
# 7           Sant Andreu  127773  134283  134783  126632  143754  126461
# 8            Sant Martí  199582  210091  211972  197409  220456  196603
# 9        Sants-Montjuïc  155330  161061  158068  150748  169975  150737
# 10  Sarrià-Sant Gervasi   64228   66886   65280   59365   65740   58837
#
#       2017    2018    2019    2020   2021
# 0   101100   98460   95093  228851  49449
# ...

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
import html

# %%
@interact
def show_recs_more_than(column=list(clean_data.select_dtypes('number').columns), 
                          x=(50, 23000, 1)):
    display(html(f'<h2>Showing records with more than {x} {column}<h2>'))
    display(clean_data.loc[clean_data[::] > x, ['district_name', '2011', '2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']])
# Out:
# interactive(children=(Dropdown(description='column', options=('2011', '2012', '2013', '2014', '2015', '2016', …

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15,7
clean_data.plot(x="district_name", y=["2011", "2012", "2013","2014","2015","2016","2017","2018","2019","2020","2021"], kind="bar")

# %% [markdown]
# #### our finding is, the unemployment rate in 2020 increased significantly
#
# ####No consta has the lowest unemplyoment rate
# ####Sant Marti has the highest unemployemnt rate

# %% [markdown]
# #### Now I want to know the total number of women & men's unemployment

# %%
# I need to better write a function for the following codes

# %%
sex_2011 = final_2011_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()
sex_2012= final_2012_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()
sex_2013= final_2013_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()
sex_2014 = final_2014_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()
sex_2015 = final_2015_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()
sex_2016 = final_2016_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()
sex_2017 = final_2017_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()
sex_2018 = final_2018_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()
sex_2019 = final_2019_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()
sex_2020 = final_2020_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()
sex_2021 = final_2021_graph.groupby(["district_name","sex"])["number"].aggregate("sum").reset_index()

# %%
sex_2011.head(4)
# Out:
#   district_name    sex  number
# 0  Ciutat Vella  Dones   45747
# 1  Ciutat Vella  Homes   72402
# 2      Eixample  Dones   92980
# 3      Eixample  Homes   90038

# %%
sex_2011=sex_2011.rename(columns = {'sex':'sex','number':'number_2011'}, inplace = False)
sex_2012=sex_2012.rename(columns = {'sex':'sex','number':'number_2012'}, inplace = False)
sex_2013=sex_2013.rename(columns = {'sex':'sex','number':'number_2013'}, inplace = False)
sex_2014=sex_2014.rename(columns = {'sex':'sex','number':'number_2014'}, inplace = False)
sex_2015=sex_2015.rename(columns = {'sex':'sex','number':'number_2015'}, inplace = False)
sex_2016=sex_2016.rename(columns = {'sex':'sex','number':'number_2016'}, inplace = False)
sex_2017=sex_2017.rename(columns = {'sex':'sex','number':'number_2017'}, inplace = False)
sex_2018=sex_2018.rename(columns = {'sex':'sex','number':'number_2018'}, inplace = False)
sex_2019=sex_2019.rename(columns = {'sex':'sex','number':'number_2019'}, inplace = False)
sex_2020=sex_2020.rename(columns = {'sex':'sex','number':'number_2020'}, inplace = False)
sex_2021=sex_2021.rename(columns = {'sex':'sex','number':'number_2021'}, inplace = False)

# %%
_sex_merge=sex_2011.merge(sex_2012, on=['district_name','sex'], how='left')
_sex_merge_=_sex_merge.merge(sex_2013, on=['district_name','sex'], how='left')
_sex_merge_=_sex_merge_.merge(sex_2014, on=['district_name','sex'], how='left')
_sex_merge_=_sex_merge_.merge(sex_2015, on=['district_name','sex'],how='left')
_sex_merge_=_sex_merge_.merge(sex_2016, on=['district_name','sex'], how='left')
_sex_merge_=_sex_merge_.merge(sex_2017, on=['district_name','sex'],how='left')
_sex_merge_=_sex_merge_.merge(sex_2018, on=['district_name','sex'],how='left')
_sex_merge_=_sex_merge_.merge(sex_2019, on=['district_name','sex'], how='left')
_sex_merge_=_sex_merge_.merge(sex_2020, on=['district_name','sex'], how='left')
_sex_merge_=_sex_merge_.merge(sex_2021, on=['district_name','sex'], how='left')

# %%
_sex_merge_.head(2)
# Out:
#   district_name    sex  number_2011  number_2012  number_2013  number_2014  \
# 0  Ciutat Vella  Dones        45747        46944        46330        43745
# 1  Ciutat Vella  Homes        72402        70168        64915        59849
#
#    number_2015  number_2016  number_2017  number_2018  number_2019  \
# 0        51290        47156        45054        45042        43791
# 1        67841        61158        56046        53418        51302
#
#    number_2020  number_2021
# 0        99503        21307
# 1       129348        28142

# %%
gender_clean_data=_sex_merge_

# %%
gender_pivot=gender_clean_data.pivot(index='district_name', columns='sex', values=['number_2011','number_2012','number_2013','number_2014','number_2015','number_2016','number_2017','number_2018','number_2019','number_2020','number_2021'])

# %%
gender_pivot.plot(kind='bar')

# %%
gender_pivot_sum=gender_pivot.sum()
gender_pivot_sum=pd.DataFrame(gender_pivot_sum)
gender_pivot_sum=gender_pivot_sum.unstack()
gender_pivot_sum=gender_pivot_sum.reset_index()

# %%
gender_women_pivot=gender_women_pivot.reset_index()

# %%
gender_pivot_sum.plot(x='y', y='action' ,figsize=(10,5), grid=True)

# %% [markdown]
# #### next idea
# covid data
# and gdp data
# and yearly total unemployment numbers + arima model

# %% [markdown]
# #### next steps tonight:
#
# set up a blog,
# change the plots for gender
# (* add interactive widgets )
# find max and min and avg: unmeplyoment per year
#
#     why?
#     -> covid
#     ->gdp
#
# -> arima model expectation for the next year ....
# I need to have time seireis dataset

# %% [markdown]
# #### monthly unemployment numbers -> I want to know monthly distribution past 10 years and want to use arima model here

# %%
final_2011_graph
time_2011 = final_2011_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()
time_2012 = final_2012_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()
time_2013 = final_2013_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()
time_2014 = final_2014_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()
time_2015 = final_2015_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()
time_2016 = final_2016_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()
time_2017 = final_2017_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()
time_2018 = final_2018_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()
time_2019 = final_2019_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()
time_2020 = final_2020_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()
time_2021 = final_2021_graph.groupby(["year","month"])["number"].aggregate("sum").reset_index()

# %%
frames_ = [time_2011,time_2012,time_2013,time_2014,time_2015,time_2016,time_2017,time_2018,time_2019,time_2020,time_2021]

time_result = pd.concat(frames_)

# %%
time_result.tail(3)
# Out:
#     year  month  number
# 11  2020     12  247442
# 0   2021      1  250071
# 1   2021      2  252392

# %%
time_pivot=time_result.pivot(index='month', columns='year', values=['number'])

# %%
time_pivot
# Out:
#          number                                                             \
# year       2011      2012      2013      2014      2015      2016     2017
# month
# 1      105456.0  112747.0  114443.0  109151.0  123415.0  111001.0  98566.0
# 2      107928.0  113736.0  114936.0  108225.0  123434.0  109447.0  99545.0
# 3      109153.0  113528.0  115154.0  107734.0  122262.0  108639.0  99059.0
# 4      108203.0  113402.0  113870.0  106398.0  119297.0  105787.0  96040.0
# 5      106774.0  112585.0  111451.0  102784.0  115405.0  102857.0  93829.0
# 6      104784.0  110521.0  107913.0  100943.0  113140.0  101470.0  92132.0
# 7      104929.0  110675.0  108192.0  101997.0  113601.0  101676.0  92742.0
# 8      107625.0  112381.0  108606.0  102096.0  114657.0  102571.0  94163.0
# 9      108250.0  112088.0  108706.0  101045.0  112644.0  100698.0  92095.0
# 10     109266.0  112479.0  109984.0  101559.0  112357.0   99476.0  92511.0
# ...

# %%
time_pivot.plot()

# %%
sum_=time_pivot.sum(axis=0) 
sum_
# Out:
#         year
# number  2011    1290898.0
#         2012    1349653.0
#         2013    1331213.0
#         2014    1241591.0
#         2015    1393738.0
#         2016    1242084.0
#         2017    1138109.0
#         2018    1082928.0
#         2019    1053887.0
#         2020    2320643.0
#         2021     502463.0
# dtype: float64

# %%
print("Monthly average registered unemplyoment people in 2019", 1053887/12)
print("Monthly average registered unemplyoment people in 2020", 2320643/12)
print("Monthly average registered unemplyoment people in 2021" ,502463/2)
# Out:
# Monthly average registered unemplyoment people in 2019 87823.91666666667
# Monthly average registered unemplyoment people in 2020 193386.91666666666
# Monthly average registered unemplyoment people in 2021 251231.5

# %%
print("Monthly Average registered unemployment increase rate (2019->2020)",(193387/87824)*100)
print("Monthly Average registered unemployment increase rate (2020->2021)",(251231/193387)*100)
# Out:
# Monthly Average registered unemployment increase rate (2019->2020) 220.19835124795043
# Monthly Average registered unemployment increase rate (2020->2021) 129.91100746172185

# %% [markdown]
# #### Now, I want to now predict next year's unemplyoment rate

# %% [markdown]
# #### combined two separate columns to one

# %%
time_result['Date'] = pd.to_datetime(time_result.year.astype(str) + '-' + time_result.month.astype(str))

# %%
time_result=time_result.drop(columns='month')
time_result=time_result.drop(columns='year')

# %%
time_result.head(2)
# Out:
#             number
# Date
# 2011-01-01  105456
# 2011-02-01  107928

# %%
from datetime import timedelta
time_result['Date'] = pd.to_datetime(time_result['Date'], format='%Y%m%d')

# %%
#Holt-Winters’ Seasonal Method ->Holt-Winters’ Seasonal Method for data with trend and/or seasonality
import statsmodels.api as sm
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
import warnings
import matplotlib.pyplot as plt
y = time_result['number']
fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='Monthly')
ax.plot(y.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='Monthly Mean Resample')
ax.set_ylabel('Orders')
ax.legend();

# %% [markdown]
# #### 1. Simply plotting general trends, using the mean

# %% [markdown]
# #### 2.Decompose the dataset

# %%
def seasonal_decompose (y):
    decomposition = sm.tsa.seasonal_decompose(y, model='additive',extrapolate_trend='freq')
    fig = decomposition.plot()
    fig.set_size_inches(14,7)
    plt.show()

# %%
seasonal_decompose(y)

# %% [markdown]
# #### check for the stationary of the data

# %%
def test_stationarity(timeseries, title):
    
    #Determing rolling statistics
    rolmean = pd.Series(timeseries).rolling(window=12).mean() 
    rolstd = pd.Series(timeseries).rolling(window=12).std()
    
    fig, ax = plt.subplots(figsize=(16, 4))
    ax.plot(timeseries, label= title)
    ax.plot(rolmean, label='rolling mean');
    ax.plot(rolstd, label='rolling std (x10)');
    ax.legend()

# %%
pd.options.display.float_format = '{:.8f}'.format
test_stationarity(y,'raw data')

# %%
# Augmented Dickey-Fuller Test
from statsmodels.tsa.stattools import adfuller

def ADF_test(timeseries, dataDesc):
    print(' > Is the {} stationary ?'.format(dataDesc))
    dftest = adfuller(timeseries.dropna(), autolag='AIC')
    print('Test statistic = {:.3f}'.format(dftest[0]))
    print('P-value = {:.3f}'.format(dftest[1]))
    print('Critical values :')
    for k, v in dftest[4].items():
        print('\t{}: {} - The data is {} stationary with {}% confidence'.format(k, v, 'not' if v<dftest[0] else '', 100-int(k[:-1])))

# %%
ADF_test(y,'raw data')
# Out:
#  > Is the raw data stationary ?
# Test statistic = 0.072
# P-value = 0.964
# Critical values :
# 	1%: -3.4865346059036564 - The data is not stationary with 99% confidence
# 	5%: -2.8861509858476264 - The data is not stationary with 95% confidence
# 	10%: -2.579896092790057 - The data is not stationary with 90% confidence

# %% [markdown]
# #### Detrending

# %%
# Detrending
y_detrend =  (y - y.rolling(window=12).mean())/y.rolling(window=12).std()

test_stationarity(y_detrend,'de-trended data')
ADF_test(y_detrend,'de-trended data')
# Out:
#  > Is the de-trended data stationary ?
# Test statistic = -2.106
# P-value = 0.242
# Critical values :
# 	1%: -3.4989097606014496 - The data is not stationary with 99% confidence
# 	5%: -2.891516256916761 - The data is not stationary with 95% confidence
# 	10%: -2.5827604414827157 - The data is not stationary with 90% confidence

# %%
# Differencing
y_4lag =  y - y.shift(4)

test_stationarity(y_4lag,'4 lag differenced data')
ADF_test(y_4lag,'4 lag differenced data')
# Out:
#  > Is the 4 lag differenced data stationary ?
# Test statistic = -1.363
# P-value = 0.600
# Critical values :
# 	1%: -3.4924012594942333 - The data is not stationary with 99% confidence
# 	5%: -2.8886968193364835 - The data is not stationary with 95% confidence
# 	10%: -2.5812552709190673 - The data is not stationary with 90% confidence

# %% [markdown]
# #### ok it,s nonstationary nad I can't make it staionary so I will just go for Holtwinters model as it can deal with
# #### non-staionary timeseiries

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.seasonal import seasonal_decompose 
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
y
# Out:
# Date
# 2011-01-01    105456
# 2011-02-01    107928
# 2011-03-01    109153
# 2011-04-01    108203
# 2011-05-01    106774
#                ...
# 2020-10-01    240631
# 2020-11-01    244632
# 2020-12-01    247442
# 2021-01-01    250071
# 2021-02-01    252392
# Freq: MS, Name: number, Length: 122, dtype: int64

# %%
# Set the frequency of the date time index as Monthly start as indicated by the data
time_result.index.freq = 'MS'
# Set the value of Alpha and define m (Time Period)
m = 12
alpha = 1/(2*m)

# %%
time_result
# Out:
#             number
# Date
# 2011-01-01  105456
# 2011-02-01  107928
# 2011-03-01  109153
# 2011-04-01  108203
# 2011-05-01  106774
# ...            ...
# 2020-10-01  240631
# 2020-11-01  244632
# 2020-12-01  247442
# 2021-01-01  250071
# 2021-02-01  252392
#
# [122 rows x 1 columns]

# %%
time_result['HWES1'] = SimpleExpSmoothing(time_result['number']).fit(smoothing_level=alpha,optimized=False,use_brute=True).fittedvalues
time_result[['number','HWES1']].plot(title='Holt Winters Single Exponential Smoothing');
# Out:
# /Users/mitarbeiter/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(

# %% [markdown]
# #Single HWES
#
# #it did not fit well, because single ES does not work for data with trends and seasonality

# %% [markdown]
# #### Double HWES
# #### Double ES, on both Additive and Multiplicative Trend

# %%
time_result['HWES2_ADD'] = ExponentialSmoothing(time_result['number'],trend='add').fit().fittedvalues
time_result['HWES2_MUL'] = ExponentialSmoothing(time_result['number'],trend='mul').fit().fittedvalues
time_result[['number','HWES2_ADD','HWES2_MUL']].plot(title='Holt Winters Double Exponential Smoothing: Additive and Multiplicative Trend');
# Out:
# /Users/mitarbeiter/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# /Users/mitarbeiter/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /Users/mitarbeiter/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %% [markdown]
# #### Triple HWES

# %%
time_result['HWES3_ADD'] = ExponentialSmoothing(time_result['number'],trend='add',seasonal='add',seasonal_periods=12).fit().fittedvalues
time_result['HWES3_MUL']= ExponentialSmoothing(time_result['number'],trend='mul',seasonal='mul',seasonal_periods=12).fit().fittedvalues
time_result[['number','HWES3_ADD','HWES3_MUL']].plot(title='Holt Winters Triple Exponential Smoothing: Additive and Multiplicative Seasonality');
# Out:
# /Users/mitarbeiter/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# /Users/mitarbeiter/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /Users/mitarbeiter/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %% [markdown]
# #### both Additive and Multiplicative Seasonality are added

# %%
time_result.index.freq = 'MS'
# Split into train and test set
train_result = time_result[:112]
test_result = time_result[112:]

# %%
fitted_model = ExponentialSmoothing(train_result['number'],trend='mul',seasonal='mul',seasonal_periods=4).fit()
test_predictions = fitted_model.forecast(4)
# Out:
# /Users/mitarbeiter/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# /Users/mitarbeiter/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
test_predictions
# Out:
# 2020-05-01   202773.70638942
# 2020-06-01   246052.90867547
# 2020-07-01   304148.62389491
# 2020-08-01   368475.71059505
# Freq: MS, dtype: float64

# %%
train_result['number'].plot(legend=True,label='TRAIN')
test_result['number'].plot(legend=True,label='TEST')
test_predictions.plot(legend=True,label='PREDICTION')

plt.title('Train, Test and Predicted Test using Holt Winters')
# Out:
# Text(0.5, 1.0, 'Train, Test and Predicted Test using Holt Winters')
